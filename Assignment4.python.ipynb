# %% [markdown]
# ## Tuple:
#
# * tuble is immutabale,allow duplicate Values ,and tuple is  ordered. also  hetrogenious Data types

# %%
t1=(10,20,20,30,40,"satheesh",True,90.00)
t2=(90.10,230,4557)
t1.index(30)
t1.rindex()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 4
#       2 t2=(90.10,230,4557)
#       3 t1.index(30)
# ----> 4 t1.rindex()
#
# AttributeError: 'tuple' object has no attribute 'rindex'

# %% [markdown]
# ### Operter that will support on tuble
# 1. support '+' operater (arithmetic)
#  2. support ' * ' operater - * means support only repetation operter (Arithmetic)
#    *  (only this Arithmetic operter is support on tuble)

# %%
t1=(10,20,30,40)
t2=(90.10,230,4557)
t1+t2
# Out:
# (10, 20, 30, 40, 90.1, 230, 4557)

# %%
t1=(10,20,30,40)
t2=(90.10,230,4557)
t1-t2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 t1=(10,20,30,40)
#       2 t2=(90.10,230,4557)
# ----> 3 t1-t2
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %%
t1=(10,20,30,40)
t2=(90.10,230,4557)
t1*t2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 t1=(10,20,30,40)
#       2 t2=(90.10,230,4557)
# ----> 3 t1*t2
#
# TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
t1=(10,20,30,40)
t2=(90.10,230,4557)
t1*2
# Out:
# (10, 20, 30, 40, 10, 20, 30, 40)

# %%
t1=(10,20,30,40)
t2=(90.10,230,4557)
t1%t2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 t1=(10,20,30,40)
#       2 t2=(90.10,230,4557)
# ----> 3 t1%t2
#
# TypeError: unsupported operand type(s) for %: 'tuple' and 'tuple'

# %% [markdown]
# ### 2.Assignment Operater
#
# #### operter that will support on tuple
# * '+=' operter support in tuble.
# * '*=' - operter support in tuple.

# %%
t1=(10,20,30,40)
t2=(90.10,230,4557)
t1=t1+t2
print(t1)
# Out:
# (10, 20, 30, 40, 90.1, 230, 4557)

# %%
t1=(10,20,30,40)
t2=(90.10,230,4557)
t1=t1-t2
print(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 t1=(10,20,30,40)
#       2 t2=(90.10,230,4557)
# ----> 3 t1=t1-t2
#       4 print(t1)
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %%
t1=(10,20,30,40)
t2=(90.10,230,4557)
t1=t1*t2
print(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 t1=(10,20,30,40)
#       2 t2=(90.10,230,4557)
# ----> 3 t1=t1*t2
#       4 print(t1)
#
# TypeError: can't multiply sequence by non-int of type 'tuple'

# %%
t1=(10,20,30,40)
t2=(90.10,230,4557)
t1=t1*3
print(t1)
# Out:
# (10, 20, 30, 40, 10, 20, 30, 40, 10, 20, 30, 40)

# %% [markdown]
# ### 3.Comparison Operter
#
# #### * All operater support on tuple.

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1>t2
# Out:
# False

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1<t2
# Out:
# True

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1>=t2
# Out:
# False

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1<=t2
# Out:
# True

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1>t2

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1==t2
# Out:
# False

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1 !=t2
# Out:
# True

# %% [markdown]
# ### 4. Logical Operater
#
# ### * All Logical operter support on tuble

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1 and t2
# Out:
# (90.1, 230, 4557, 8.9, 'satheesh')

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1 or t2
# Out:
# (10, 20, 30, 40, 'satheeh')

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
not t1
# Out:
# False

# %% [markdown]
# #### 5.Identity Operter:
#
# ### * all Identity Operter support on tuple.

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1 is t2
# Out:
# False

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1 is not t2
# Out:
# True

# %% [markdown]
# ### 6.Membership operter
#
# #### * All Not in Membership operter support in tuble.

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1 in t2
# Out:
# False

# %%
t1=(10,20,30,40,"satheeh")
t2=(90.10,230,4557,8.9,"satheesh")
t1 not in t2
# Out:
# True
