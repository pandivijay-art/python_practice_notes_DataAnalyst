# %% [markdown]
# Day 12

# %% [markdown]
# ## What is Command

# %% [markdown]
# ### command is a line ,that is not executed by compiler ,and it is code make easier and understandable ,and used to write notes in python

# %% [markdown]
# only one command in python

# %% [markdown]
# ### Single Line Command

# %% [markdown]
# Use "#" - hastak symbol is used for single line command.

# %%
List1=[10,20,50,"satheesh","pandi"]
list2=[90,203,56,45,877]

# %%
List1+list2
# Out:
# [10, 20, 50, 'satheesh', 'pandi', 90, 203, 56, 45, 877]

# %%
List1-list2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 List1-list2
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
List1&ist2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 List1&ist2
#
# NameError: name 'ist2' is not defined

# %%
List1* 2    # * used in repetation operater.
# Out:
# [10, 20, 50, 'satheesh', 'pandi', 10, 20, 50, 'satheesh', 'pandi']

# %%
list1=[210,2393]
list2=[24,4546]
list1=list1+list2
list1
# Out:
# [210, 2393, 24, 4546]

# %% [markdown]
# ## Arithmetic Operter and assignment operater that will support in list

# %% [markdown]
# 1.+,=+,* , *=  (THis operation used in list)(Remaing  operstion is not support)

# %% [markdown]
# Repetation Operater
#
# for example:
# * list1=[210,2393]
# * list2=[24,4546]
# * list1 * 2
#
# * - astrick is a repetation operater(it is used to repeat given multiple time )

# %% [markdown]
# (when python has Defined meanigfull behaviour for that operater )

# %% [markdown]
# ### Comparison Operter:
#
# this operater does not return the same data type ,will return only true or false,like compare two or more values.
#
# all the comparsion operater support on list

# %% [markdown]
# ### Lexicographical COmparision:
#
# compare  sequence element by element ,from left to right ,untill the first ellement is found.

# %%
list1=["Satheesh",9,829]
list2=["sathesh",20,209,240]
list1>list2
# Out:
# False

# %%
list1=["Satheesh",9,829]
list2=["sathesh",20,209,240]
list1<list2
# Out:
# True

# %%
list1=["Satheesh",9,829]
list2=["sathesh",20,209,240]
list1!=list2
# Out:
# True

# %% [markdown]
# ## Logical Operater
#
# #### All the Logical operater support on List

# %% [markdown]
# #### unlike comparison operater,but return the same data type.

# %% [markdown]
# AND - and operater (return the first false value,if provideed all values is true return the last true Values)

# %%
list1=["sa",10,20,30]
list2=["loj",90,49,454]
list1 and list2   #,if provideed all values is true return the last true Values)
# Out:
# ['loj', 90, 49, 454]

# %% [markdown]
# ### OR - return the first true Value ,if all provited value is false return the first False Value)

# %%
list1=["sa",10,20,30]
list2=["loj",90,49,454]
list1 and list2
# Out:
# ['sa', 10, 20, 30]

# %%
list1={}
list2=[]
list1 or list2
# Out:
# []

# %% [markdown]
# ### Not - oppsite of Boolean Values
#
# take one operand ,and analys the truth and return the oppsoite of boolean Value

# %%
list1=["sa",10,20,30]
list2=["loj",90,49,454]
not list2
# Out:
# False

# %% [markdown]
# #### Identify operater:
# (all the identical operter support on list)
#
# ### identify operater determines two object refer the same address in memory

# %% [markdown]
# ### is operater

# %% [markdown]
# #### if two objext refer the same address in momory ,now return the true and otherwise return False.

# %%
a=[10,20,430,465]
b=a
print(id(a))
print(id(b))
a is b
# Out:
# 2337863420096
# 2337863420096
# True

# %%
a=[10,20,430,465]
b=a
print(id(a))
print(id(b))
a is not  b
# Out:
# 2337855323008
# 2337855323008
# False

# %% [markdown]
# ### Membership operter

# %% [markdown]
# Membership operater is used to check on exsisting element

# %% [markdown]
# ### in operetr

# %% [markdown]
# if the given elemnt exist on the sequence ,return the true

# %% [markdown]
# ### not in operter

# %% [markdown]
# if the given element not exist in sequence ,return the False.

# %%
a=[10,20,40,50,60]
b=[90,46.68,24,76]
190 in a
# Out:
# False

# %%
a=[10,20,40,50,60]
b=[90,46.68,24,76]
190 not in a
# Out:
# True

# %% [markdown]
# ## Tuple

# %% [markdown]
# tuble is creted in 2 ways:
#
# 1. profession way is used () parentheses to create tuble (it is a normal way)

# %%
a=(10,20,402,"satheesh")
type(a)
# Out:
# tuple

# %% [markdown]
# 2.aneway paranthesis not decided which is tuble or not tuble ,where we assign more values in object that python automatically will become tuble

# %%
a=10
type(a)
# Out:
# int

# %%
a=10,20
type(a)
# Out:
# tuple

# %% [markdown]
# #### internally python function used tuble ,when return more then one result at the time ,it wil return automatically tuble)

# %% [markdown]
# ### Nested Indexing

# %% [markdown]
# #### nested indexing can be used when elemnt itself contain another indexable sequence

# %%
a=[10,20,[20,30,40]]
b=[10,20,[90,100,10]]
a[2][2]
# Out:
# 40

# %% [markdown]
# ### dir() - return the list or methods available in object.

# %%
a=[10,20]
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# ### dictionary

# %% [markdown]
# ##### 1.dictioanry is a Mapping Structure
# ##### 2.its contain key and Value paires
# ##### 3.and it is mutable ,hetrogenious ,partially orders,only value contain duplicate Values not key
# ##### 4.heavily used in semi structure area

# %% [markdown]
# Create Ways :
# 1. use curly bracis {}

# %% [markdown]
# 2.use dict() (this is build in function)

# %% [markdown]
# ### proffessional pointes

# %% [markdown]
# #### dict only will allow hasable sequences  as a key

# %% [markdown]
# #### Hasable - collection of immutable values

# %% [markdown]
# #### Unhasable - Collection of mutable Values

# %%
books={[10,20]:"satheeshj",
"first":"kumar",
 "last":"pandi"     }
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 books={[10,20]:"satheeshj",
#       2 "first":"kumar",
#       3  "last":"pandi"     }
#
# TypeError: unhashable type: 'list'

# %%
books={{10,20}:"satheeshj",
"first":"kumar",
 "last":"pandi"   }
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 books={{10,20}:"satheeshj",
#       2 "first":"kumar",
#       3  "last":"pandi"   }
#
# TypeError: unhashable type: 'set'

# %%
books={(10,20):"satheeshj",
"first":"kumar",
 "first":"pandi"   }
books["first"]
# Out:
# 'pandi'

# %% [markdown]
# ### Overwrie :
#
# * older Value repeated by the new Value
# * overwrite in older Value

# %%
name="satheesh"
name="pandi"
print(name)
# Out:
# pandi

# %%
name=10
name=20
print(name)
# Out:
# 20
