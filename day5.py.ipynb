# %% [markdown]
# ### day5 of python Practice

# %% [markdown]
# ### In datatype Boolean data type in python?

# %% [markdown]
# #### entire datatype contain only two values ,1.true 2.false
# * purpose - used do control flow statement ,validation ,Logical ,comparision ,identicaal and Membership

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 satheesh = False
# ----> 2 print(Satheesh)
#
# NameError: name 'Satheesh' is not defined

# %% [markdown]
# ### what is float

# %% [markdown]
# a decimal point with fraction (0.8998) is known as Float

# %% [markdown]
# ## 2nd bulid in function what is round()

# %% [markdown]
# a build in function take arguments (floatvalue number,number of fraction)

# %% [markdown]
# for ex

# %%
var3=9.54676

# %%
round(var3,2)
# Out:
# 9.55

# %%
number=7.768458
round(number,3)
# Out:
# 7.768

# %%
round(number,2)
# Out:
# 7.77

# %% [markdown]
# #### round function is used do reduce the decimal places of a number to the required number of digites

# %% [markdown]
# #### null= null is a empty point,cannot compare with any logic(not even in zero ,literrelly nothing)

# %% [markdown]
# ### None Datatype represent emptyness,literally noting inside .

# %%
phone_number=9597227440
print(phone_number)
# Out:
# 9597227440

# %% [markdown]
# ## what is complex?
#
# real value along with imaginary part is known as complex value. we use j for defining a imginary value
# * .real retriving the real Value
# * .imag retriving the imaginary part on a complex value object

# %% [markdown]
# example

# %%
var=5+7j
var
# Out:
# (5+7j)

# %%
var.real
# Out:
# 5.0

# %%
var.imag
# Out:
# 7.0

# %%
slope=7+8j

# %%
slope.real
# Out:
# 7.0

# %%
slope.imag
# Out:
# 8.0

# %% [markdown]
# ## 3 rd Build in Funactionm

# %% [markdown]
# ### type() = return the type of the given object

# %% [markdown]
# #### for ex

# %%
mark=100
type(mark)
# Out:
# int

# %%
height=6.89
type(height)
# Out:
# float

# %% [markdown]
# #### in python everthing is an object for ex:like int,string,tuble ,class and function . object is a instance of class.

# %%
n="hello"
dir(n)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %% [markdown]
# #### dir-takes an class object return the property ,methodes,and magical methodes from the class object.

# %% [markdown]
# ## list out of importand String Method

# %% [markdown]
# #### .upper(),.lower(),.title(),.count(),.isalpha(),,.spilt(),.index(),.find(),.replace(),.capitalize(),.format()

# %%
name="Satheesh"
name.lower()
# Out:
# 'satheesh'

# %%
name.isalpha()
# Out:
# True

# %%
name.upper()
# Out:
# 'SATHEESH'

# %%
name.count('e')
# Out:
# 2

# %%
name.split()
# Out:
# ['Satheesh']

# %%
name='satheesh'
name.replace("e","s")
# Out:
# 'sathsssh'

# %% [markdown]
# ## what is Casting?
#
# #### taking an object and obtaining the another version of the given object by not changing the current object

# %% [markdown]
# diff convert and casting

# %%
name=int(input())
# Out:
#  89

# %% [markdown]
# ## casting is not type conversion.

# %%
i=8
str(i)
# Out:
# '8'

# %%
s="satheesh"
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 s="satheesh"
# ----> 2 int(s)
#
# ValueError: invalid literal for int() with base 10: 'satheesh'

# %%
bool(s)
# Out:
# True

# %% [markdown]
# ## how are flase values in python?
#
# except -- false ,0,none,'',(),[],{},set() apart from this everything is a true in python

# %%
name="sa"
bool(name)
# Out:
# True

# %%
s=()
bool(s)
# Out:
# False

# %% [markdown]
# #### 1.try all the string method assignment
# #### 2.try-- int(),str(),,bool(),float(),complex(),bin(),oct(),hex(), on string ,complex,bool ,none ,float

# %% [markdown]
# ## what is Indexing?
#
# beginner level:accesing the data based on the position is caled index,
#
# * 1.position based data access - 1.positive indexing ,2.nagative indexing (give position and return data)
# * 2.Data based position access : give data aand (we use .index and it will return positive index position)

# %% [markdown]
# #### postive indexing start from 0  it goest to left side to right side
# #### nagative indexing start from  -1 it goes to right side to left side

# %%
s="satheesh"
s[0]
# Out:
# 's'

# %%
s="pandi"
s[-9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 s="pandi"
# ----> 2 s[-9]
#
# IndexError: string index out of range

# %%
s="pandi"
print(s.index("i"))
# Out:
# 4

# %% [markdown]
# #### in int - no possible

# %% [markdown]
# ####  indexerrer=string intext out of range

# %%
a[2000
    a.index
    ]

# %%
rindex()-last occur

# %% [markdown]
# ### diffence Betweeen index and find

# %% [markdown]
# ## index- take data as a argument and retuen the position ,but ,if not in the data ,retuen the error,they cause crash
# ## find- take data as a argument and return the position of given data ,if not in data ,return -1.

# %% [markdown]
# for ex

# %%
name="satheesh pandi"

print(name.index("a"))    # return the position of first occurence
print(name.rindex("e"))  #rindex means return the position in last accurence
# Out:
# 1
# 5

# %% [markdown]
# ## find

# %%
name="satheesh pandi"
print(name.find("i"))
print(name.rfind("i"))
print(name.find("o"))
# Out:
# 13
# 13
# -1
