# %% [markdown]
# ### Adding Data into set

# %% [markdown]
# ### Add function will add the recordes in random position in your set

# %%
s1={10,20,50,60,79}
s1.add(10)
print(s1)
# Out:
# {50, 20, 10, 60, 79}

# %%
s1={10,20,50,60,79}
s1.add(43)
print(s1)
# Out:
# {50, 20, 10, 43, 60, 79}

# %% [markdown]
# ### .update()

# %% [markdown]
# ##### we use .update ,unify the two sets and automatically removed duplicate Values.only return unque recordes in both sets. old set will be modifies,does not return the Value.

# %%
s1={90,34,56,343,121,76}
s32={90,67,56,345}
s1.update(s32)
# Out:
# {34, 67, 345, 76, 343, 56, 121, 90}

# %%
s1={90,34,56,343,121,76}
s32={90,67,56,345}
s2=s1.update(s32)    # .update() - does not return any Values.just modify the old set
print(s2)
# Out:
# None

# %% [markdown]
# #### How do remove data in set

# %%
s1={20,30,1,True}
print(s1)
# Out:
# {1, 20, 30}

# %% [markdown]
# ## A set keeps the first representaion of equal Values

# %% [markdown]
# ## 1.pop() - pop removes the random element in the set - not recommend by proffessional way beecause not knowing which elemnt is delete. pop takes no arugumenr

# %%
s1={10,20,30,40,50,60}
s1.pop()
# Out:
# 50

# %%
s1={10,20,30,40,50,48,60}
s1.pop()
# Out:
# 48

# %% [markdown]
# ## 2.remove() -  use highly remove particular data in dataset ,if not existing data ,it will throw error.(remove() raise the keyerror because python treat set elemnt like keys ,so if not found in the set , raise keyerror.)

# %%
s1={10,20,30,40,50,60}
s1.remove(60)
print(s1)
# Out:
# {50, 20, 40, 10, 30}

# %%
s1={10,20,30,40,50,60}
s1.remove(100)  # why key error:
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 s1={10,20,30,40,50,60}
# ----> 2 s1.remove(100)
#
# KeyError: 100

# %% [markdown]
# ### 3.discart() - it is also remove specific elemnt in the set , but it wont return keyt error , if doesnot existes.it is proffessional way to remove data in set.because this one is wont raise error.

# %%
s1={10,20,40,50,70,80}
s1.discard(80)
print(s1)
# Out:
# {50, 20, 70, 40, 10}

# %%
s1={10,20,40,50,70,80}
s1.discard(800)
print(s1)
# Out:
# {80, 50, 20, 70, 40, 10}

# %% [markdown]
# ## 4.Clean() - remove the all elemnts in the set ,and return the empty set,it takse no argument

# %%
s1={10,20,40,50,70,80}
s1.clear()
print(s1)
# Out:
# set()

# %% [markdown]
# ### What is the professional way to return data in dictianry

# %% [markdown]
# fro example in normal beginner way:

# %%
d1={"satheesh":90,"pandi":100}
d1["satheesh"]
# Out:
# 90

# %% [markdown]
# But ,in normal ways ,if key is doesnot exist ,it will return error.

# %%
d1={"satheesh":90,"pandi":100}
d1["sathe"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 2
#       1 d1={"satheesh":90,"pandi":100}
# ----> 2 d1["sathe"]
#
# KeyError: 'sathe'

# %% [markdown]
# ## in proffessional way we use .get()

# %% [markdown]
# ### get()- get also retrive the data from dictioanry ,but it does not through error. to prevent the program from crashing
# ### .get() also us to define Default Values

# %%
d1={"satheesh":90,"pandi":100}
d1.get("padsd","not found")
# Out:
# 'not found'

# %% [markdown]
# ### Unique operation  that only set allow us to

# %% [markdown]
# ### 1.union() - unifying the recordes of given sets and return the unique Values .it does not allow duplicateValues. and union and update() also perform same concept  but ,update will be modified the original set ,and unique return the value ,does not modify old set.;

# %%
s1={10,20,30,50,60}
s2={10,87,56,343,321}
s1.union(s2)
# Out:
# {10, 20, 30, 50, 56, 60, 87, 321, 343}

# %%
s1={10,20,30,50,60}
s2={10,87,56,343,321}
s1&s2
# Out:
# {10}

# %%
employee_skills = {
    "Python", "SQL", "Excel", "Power BI",
    "Tableau", "Statistics", "Git", "AWS"
}

required_skills = {
    "Python", "SQL", "Excel",
    "Power BI", "Statistics", "Azure"
}

result=employee_skills.union(required_skills)
result
# Out:
# {'AWS',
#  'Azure',
#  'Excel',
#  'Git',
#  'Power BI',
#  'Python',
#  'SQL',
#  'Statistics',
#  'Tableau'}

# %% [markdown]
# ### 2.intersection

# %% [markdown]
# ###  from the all the set element that are appearing commanly will be returned
# ###  return the comman element in the given sets.

# %%
s1={10,20,30,50,60}
s2={1,87,56,343,321}
s3=s1.intersection(s2)
print(s3)
# Out:
# set()

# %% [markdown]
# ## diff between union and intersection

# %% [markdown]
# ### union unifying two or more sets and return only unique Values ,not allow duplicate,
# ### in intersection ,only return comman elelments.

# %% [markdown]
# ### difference() - finding the Values that are present in one set but not in another set.
#
# ### (the unique Values fisrt set is contain while comparing with seconf set)

# %%
s1={10,20,30,50,60}
s2={10,87,56,343,321}
s1.difference(s2)
# Out:
# {20, 30, 50, 60}

# %% [markdown]
# #### mea of subtraction :
#
# ### taking of one quantity away from another quantity

# %% [markdown]
# ### symmetric differnce:

# %% [markdown]
# #### return uncommon element in the given set. remove the common element.

# %%
s1={10,20,30,50,60}
s2={10,87,56,343,321}
s2.symmetric_difference(s1)
# Out:
# {20, 30, 50, 56, 60, 87, 321, 343}

# %% [markdown]
# ### SUbset() - if a set contains fewer element Only existing in another set , for that current set is subset.

# %%
s1={10,20,30,}
s2={10,20,30,87,56,343,321}
s1.issubset(s2)
# Out:
# True

# %% [markdown]
# ## superset() -contain  all the elements of another set ,and it may also a in extra elements

# %%
s1={10,20,30,40}
s2={10,20,30,87,56,343,321}
print(s1.issubset(s2))
print(s2.issuperset(s1))
# Out:
# False
# False

# %% [markdown]
# ### disjoint() -

# %% [markdown]
# ### if two sets does not have anything in common known as disjoint

# %%
s1={10,20,30,40}
s2={10,20,30,87,56,343,321}
s1.isdisjoint(s2)
# Out:
# False

# %% [markdown]
# ## frozenset()

# %% [markdown]
# Takes a mutable objext and convert as a immutable object
# * another version of immutable Objext

# %%
l=[10,20,40]
l[0]=20
print(l)
# Out:
# [20, 20, 40]

# %% [markdown]
# ### if we use frozenset

# %%
result=frozenset(l)

# %%
result
# Out:
# frozenset({20, 40})

# %%
result[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 result[0]=100
#
# TypeError: 'frozenset' object does not support item assignment

# %%
l=range(-1)
l
# Out:
# range(0, -1)

# %%
range(10)
print(range(10))
# Out:
# range(0, 10)

# %%
list(range(-1))
# Out:
# []

# %% [markdown]
# ## range()

# %% [markdown]
# ### range is a function ,it does not create Data Structure ,it will generate the iterable object .
# * homogenous
# * orderred
# * no duplicate allowed
# * immutable

# %% [markdown]
# range example

# %%
list1=range(8)
print(list(list1))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
list1=range(0,8)
print(list(list1))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
list1=range(2,15,3)
print(list(list1))
# Out:
# [2, 5, 8, 11, 14]

# %%
list1=range(12,3,-2)
print(list(list1))
# Out:
# [12, 10, 8, 6, 4]

# %%
list1=range(-2,8,2)
print(list(list1))
# Out:
# [-2, 0, 2, 4, 6]
