# %%
list1=[10,20,30,"Satheesh"]
list1.pop()
list1
# Out:
# [10, 20, 30]

# %%
li=[10,20,30]
del li

# %%
list1=[10,20,30,"Satheesh",20]
list1.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 list1=[10,20,30,"Satheesh",20]
# ----> 2 list1.remove()
#
# TypeError: list.remove() takes exactly one argument (0 given)

# %%
list1
# Out:
# [10, 30, 'Satheesh', 20]

# %%
list1=[10,20,30,"Satheesh",20]
list1.clear()

# %%
list1
# Out:
# []

# %%
list1=[10,20,30,90,20]
list1.sort()

# %%
 list1
# Out:
# [10, 20, 20, 30, 90]

# %%
list1=[10,20,30,40,50]
list2=sorted(list1)
list2
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# ### Ways do delete a recordfrom your list

# %% [markdown]
# #### pop() - usually pop method is used to delete the element end of the list (delete element at last)
# * with argument delete the spicific element in the list,and the return the deletd elemenet
# * also pop is a position based deletion.
# * syntax
# * name.pop(index)

# %%
name=["satheesh","pandi",12,40,340,30443]
name.pop()
# Out:
# 30443

# %%
name=["satheesh","pandi",12,40,340,30443]
name1=name.pop(0)
name1
# Out:
# 'satheesh'

# %%
name=[]

# %% [markdown]
# ### delete method

# %% [markdown]
# ### delete method is used to delete the entire object as well,does not return deleted elemnt,delete the entire structure.
# * also delete is not list method ,this is python keyword

# %%
mark=[10,20,30,30]

# %%
del mark[0]

# %%
mark
# Out:
# [20, 30, 30]

# %%
mark=[10,20,30,30]
del mark

# %%
mark
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 mark
#
# NameError: name 'mark' is not defined

# %% [markdown]
# ## pop and del both are position Based deletion

# %% [markdown]
# ### remove Method

# %% [markdown]
# ### remove - this also remove on elemnt in the list , remove is data based deletion ,if give data is more then one time occured,then remove delete the first occurence in the list.

# %%
name=["satheesh","pani",320,902,101]
name.remove("pani")
name
# Out:
# ['satheesh', 320, 902, 101]

# %% [markdown]
# ### clear Method

# %% [markdown]
# ### clear method is delete the entire elemnts in the list ,and return the empty structure

# %%
name=[10,30,2020,122,3232]
name.clear()

# %%
name
# Out:
# []

# %% [markdown]
# ### How do sort a sequence ,what are all the steps to sort a seq first of all it should be homogenois sequence
# * sort is the process of arranging the specific order ,such as asending order and desenting order.

# %%
name=[10,20,30,40,44]
name.sort(reverse=True)

# %%
name
# Out:
# [44, 40, 30, 20, 10]

# %% [markdown]
# ### sorted - like sort method ,but sorted is preserve the old list and create another sequence and get result.

# %%
name=["satheesh","pandi","kumar","selvi","patti"]
ll=sorted(name,reverse=False)

# %%
print(name)
print(ll)
# Out:
# ['satheesh', 'pandi', 'kumar', 'selvi', 'patti']
# ['kumar', 'pandi', 'patti', 'satheesh', 'selvi']

# %% [markdown]
# ### Reversed() - reverse the list and to get reverse version of given object.not a list method in iteration format ,this is python build in method.

# %%
name=["satheesh","pandi","kumar","selvi","patti"]
name1=reversed(name)
print(list(name1))
# Out:
# ['patti', 'selvi', 'kumar', 'pandi', 'satheesh']

# %% [markdown]
# # iterater

# %% [markdown]
# ### iterater means is a object ,that allows you to access elemnts of a collection one at a time

# %% [markdown]
# reverse()  - also reverse is get a reverrsed version of given object,but it will modify the old list.

# %%
list1=[10,20,30,40]
list2=list1.copy()
list1.reverse()
print(list1)
print(list2)
# Out:
# [40, 30, 20, 10]
# [10, 20, 30, 40]

# %%
list1
# Out:
# [40, 30, 20, 10]

# %% [markdown]
# # Day10 end
