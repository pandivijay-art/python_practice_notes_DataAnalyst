# %% [markdown]
# ### Bitwise XOR

# %% [markdown]
# * if both input are same or identical it will be return 0
# * if both input are not same or combination ,it will be return 1.

# %%
5 ^ 6
# Out:
# 3

# %% [markdown]
# ## Bitwise Not

# %% [markdown]
# Bitwise is a uniray bit operater ,that flips every bit of number

# %%
~5
# Out:
# -6

# %%
~9
# Out:
# -10

# %%
~0
# Out:
# -1

# %% [markdown]
# ### Right shift

# %% [markdown]
# * Right shift will remove last number of bites
# * Syntax number >> (how many numbers you want remove at the end)

# %%
5>> 2
# Out:
# 1

# %% [markdown]
# ### Left Shift

# %% [markdown]
# takes argument value by the given and it will be add number bites with 0

# %%
6 << 3
# Out:
# 48

# %% [markdown]
# ### Data Strutures

# %% [markdown]
# #### Data Struture helps us to store multiple primitive and non primitive data in organished sequence ,and allow us to insert ,update ,delete and retriving efficiently.

# %% [markdown]
# we have 4 bulid in structure in Data Structre
# * list
# * tuble
# * set
# * dictionary

# %% [markdown]
# ### MUtabilty

# %% [markdown]
# THis Data Structure Allow us to Modify ,no matter ,how modifications when you make but it will never change the Address of object.
# example
# * list
# * set
# * dict

# %%
list2=[10,20,30,40,"Satheesh"]
list2[2]=90
list2
id(list2)
# Out:
# 2626694880704

# %% [markdown]
# ## Immutable

# %% [markdown]
# This Data Strcture does not allow modify or change ,after every single Modification ,this data structure it will be change their memory address
# * example
# * tuble

# %%
name=(10,20,30)
print(id(name))
name=(10,50,300)
print(id(name))
# Out:
# 2626684028224
# 2626684332672

# %% [markdown]
# ### Ordered

# %% [markdown]
# ### this Data structure allow us to indexing,slicing,pos based indexing ,data based position and reversing ,etc...

# %% [markdown]
# example: list,tuple

# %% [markdown]
# ## unorder

# %% [markdown]
# this data structure does not allow slicng ,indexing ,etc..

# %% [markdown]
# ### Hashable and unhashable

# %% [markdown]
# Hashable means contain the all element in given sequence nust be immutable.
# * example
# 1.tuble

# %% [markdown]
# UnHasable means all the elemnts in given sequence must be mutable.

# %% [markdown]
# ex: list,dict ,set

# %% [markdown]
# ### Heterogeneous and Homogeneous

# %% [markdown]
# Heterogeneous means it is allow us to store differnd types of data like int,str,tuble..

# %% [markdown]
# Homogeneous means it does not allow us store diffend types,it only stored same type.

# %%
name=[10,10.0,"satheesh"]
name
# Out:
# [10, 10.0, 'satheesh']

# %%
[,20,30,40]
# Out:
# ['satheesh', 20, 30, 40]

# %%
import numpy as nu

# %%
sat=nu.array([10,9.00,19,9.009])
print(sat)
print(sat.dtype)
# Out:
# [10.     9.    19.     9.009]
# float64

# %% [markdown]
# #### Numpy is a Homogenous Data type ,Because Numby cantain only one type of Data structure ,if we store differnd type of data types in numby ,numpy is convert them into common type of Data type.

# %% [markdown]
# ### Duplicate and Non duplicate

# %% [markdown]
# * Duplicate means we can enter repeated Values .
# * Non dupli means we cannot entered repeated Values

# %%
name=["sath","sath",10,20,10,20]
print(name)
# Out:
# ['sath', 'sath', 10, 20, 10, 20]

# %%
se={10,10,20,302}
se
# Out:
# {10, 20, 302}

# %% [markdown]
# ## List

# %% [markdown]
# * List is a mutable ,ordered and hetrogenoius and allows duplicate values.
# * list is created with symbol []
# * list is convert into the diffend data type
# * list is also store multiple datas.

# %%
list1=[10,20,20.00,"satheesh",10,]
result=tuple(list1)
print(result)
# Out:
# (10, 20, 20.0, 'satheesh', 10)

# %% [markdown]
# ### Adding single elemnt

# %%
fruit=[10,20,70,80]
fruit.append(100)    # append means add the elemnt at the last.
fruit
# Out:
# [10, 20, 70, 80, 100]

# %%
fruit1=[20,40,50,60]
fruit1.insert(0,90)   # insert add the element in specific position 
fruit1
# Out:
# [90, 20, 40, 50, 60]

# %% [markdown]
# #### Insert Syntax
#
# name.insert(First give position , next give what elemnt you want insert in the list)

# %% [markdown]
# ### Adding Sequence element
#
# #### extend() - help us to merge the two list, result will be one list.order wise appear.

# %%
Lis1=[10,20,30,40]
lis2=[100,200]
Lis1.extend(lis2)
Lis1
# Out:
# [10, 20, 30, 40, 100, 200]

# %% [markdown]
# ### + operater
#
# + "+" operater is used to  adding two differnd list and stored another list
# + we can use old element ,because not affect exsiting elemnt.

# %%
a=[10,20,30]
b=[90,90,100]
a=a+b
a
# Out:
# [10, 20, 30, 90, 90, 100]

# %% [markdown]
# "+="
# * used do modify the existing list and adding two list.
# * we cannot use old elemnt
# because ,modify the existing list ,if ,you want to old list ,we preserve the old elemnt use .copy method
