# %% [markdown]
# ### Day15

# %% [markdown]
# #### WHat is Namespace

# %% [markdown]
# ### in python program namespace is isolated from one block of code from  another block of code
# * ### we can reuse the same  Variable again and again
# * ### Main purpose is we Can control the Block of code.

# %%
a=10

def number():
    a=11
    print(a)     # isolated one block of code from another Block of code.
number()
print(a)
# Out:
# 11
# 10

# %% [markdown]
# ## Indentaion Block

# %% [markdown]
# #### An indentation block is group of Statements belongs to the same code block  , identified by consistent identication.

# %%
age=90
if age>19:
    print("Age is Older")
# Out:
# Age is Older

# %% [markdown]
# ### Control Flow Statements

# %% [markdown]
# ### these  Satements will Take python expression and if the given expression recives trur or true Values ,the python allow us to execute Block of code.otherwise not ,which is controlled by control flow satement.

# %%
if 9:
    print("ohjhhhjh")
# Out:
# ohjhhhjh

# %% [markdown]
# ### what is if key in python?

# %% [markdown]
# * if is a control flow Statement.
# * it takes the expression and given given expression generete true or true Values. it allow us to execute Block of code. otherwise ,wont execute if block

# %%
Age = 10

if  Age < 20:
    print("Eleigible for vote")
# Out:
# Eleigible for vote

# %% [markdown]
# ## Else

# %% [markdown]
# ### Else is a Sataement ,it is also associated with any python expression  ,if that associated expression generates false or False Value ,then else will executed , otherwise not executed.

# %%
name="viratsas"
if name == "virat":
    print("Greatest player")
else:
    print("He is a Good player")
# Out:
# He is a Good player

# %% [markdown]
# ### Elif:

# %% [markdown]
# ### * Condition after another Condition.
# * help us Validate one condition after another condition.
# * if the first expersion genertae false that it only goes on the second controller.
# * Stop:"
# * where the first expression generates true or true Values that is where the block stopes executing.

# %%
name=input("enter the name:")


if name == "virat":
    print("Greatest player")
elif name == "ROhit":
    print("Hitman")
elif name == "Dhoni":
    print("Master Mind")
else:
    print("He is a Good player")
# Out:
# enter the name: virat
# Greatest player

# %% [markdown]
# ### nested If

# %% [markdown]
# ### first Validate the Outer if ,outer if satisfies it will  Validate the inner if.

# %%
age = 20
if age>19:
    print ("enter your country:")
    country=input("ENter yoyr country")
    if country == "india":
        print("you Are eligible")
# Out:
# enter your country:
# ENter yoyr country india
# you Are eligible

# %%
print(10)
# Out:
# 10
