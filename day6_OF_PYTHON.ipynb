# %% [markdown]
# ### WHat is slicing
#
# #### a concept to create a substring out of the given string (out of the sequesnce)
#
# 1.start -- where we need to start the slicing
# stop -- where need to stop usually --n-1
# stop -- skipping Values in the middle

# %% [markdown]
# a concept to create a sub string out of the given string

# %%
s="satheeh"
s[0:2:]
# Out:
# 'sa'

# %%
name="satheesh"

name[0:4]
# Out:
# 'sath'

# %%
name="programming"
name[-3:-1]
# Out:
# 'in'

# %%
name

# %% [markdown]
# ## how do archive till the end of the seq?
#  we can use seq mention start only leave end as ntg
#  if we mention only end by defalud slicing will start from 0

# %%
name="satheesh"
name[1:]
name[:9]
# Out:
# 'satheesh'

# %% [markdown]
# challange 1:

# %%
data="PYTHON-DEVELOPER-2026"
print(data[0:6])
print(data[7:16])
print(data[17:])
print(data[-1::-1])
# Out:
# PYTHON
# DEVELOPER
# 2026
# 6202-REPOLEVED-NOHTYP

# %% [markdown]
# challange 2:

# %%
text="ABCDEFGHIJKLMNO"
text[-1::-2]
# Out:
# 'OMKIGECA'

# %%
email="satheesh2026@gmail.com"
print("My name is :",email[0:12])
print(email[13:])
print(email[10:10])
print("My Domain is:",email[-9::])
# Out:
# My name is : satheesh2026
# gmail.com
#
# My Domain is: gmail.com

# %% [markdown]
# ## using slicing concepts reverse A string
#  the third parameter is slicing to decide how much values want to skip

# %%
name="satheesh"
name[::-1]
# Out:
# 'hseehtas'

# %%
s="Messiii"
s[::-1]
s[::1]
# Out:
# 'Messiii'

# %%
s="satheesh pandi"
s[::-2]
# Out:
# 'inpheha'

# %%
a="programming"
a[::2]
# Out:
# 'pormig'

# %% [markdown]
# ###  INPUT TAKING FROM USER input() in python

# %% [markdown]
# ### a build in function thak takes input at runtime from user and convert as string data type.

# %%
val=eval(input("enter the number 1:"))
val2=eval(input("Enter the number 2:"))
total=val+val2
print(total)
# Out:
# enter the number 1: 7
# Enter the number 2: 3
# 10

# %%
int("95")
# Out:
# 95

# %%
# int("25") # string represemt integer so conversion is available
# int(25)  
# int(25.344) # convert float decimal als0 
int("34")
# Out:
# 34

# %% [markdown]
# ## eval()

# %% [markdown]
# #### a function take a string input and convert it is python code or expression

# %%
"print(5+3+2)"
# Out:
# 'print(5+3+2)'

# %%
eval("print(5+3+2)")
# Out:
# 10

# %% [markdown]
# #### using eval() -- taking input from user (Professional Way)

# %%
user=eval(input("enter the name:"))
pas=eval(input("enter the pass:"))
# Out:
# enter the name: satheesh
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 user=eval(input("enter the name:"))
#       2 pas=eval(input("enter the pass:"))
#
# File <string>:1
#
# NameError: name 'satheesh' is not defined

# %% [markdown]
# # Calculaiton project

# %%
number1=eval(input("ENter the Number1:"))
number2=eval(input("ENter the number2:"))

print("the addition is:",number1+number2)
print("The Subtraction is:",number1-number2)
print("The Multiplection is:",number1*number2)
print("the division is:",number1/number2)
# Out:
# ENter the Number1: 10
# ENter the number2: 20
# the addition is: 30
# The Subtraction is: -10
# The Multiplection is: 200
# the division is: 0.5

# %% [markdown]
# practice 1  way:

# %% [markdown]
# what is string formating and how many types are there?
# replace the dummy place holders in the given sentences using actual values.

# %%
cus_name=input("enter the name:")
cus_salary=eval(input("enter the salary:"))

print("the cutomer name is %s  and salary is %f "%(cus_name,cus_salary))
# Out:
# enter the name: siuuu
# enter the salary: 1000
# the cutomer name is siuuu  and salary is 1000.000000

# %% [markdown]
# ### example for format print

# %%
name="Satheesh"
print("My name is %s"%name)
# Out:
# My name is Satheesh

# %%
price="99.5"
print("The price is %d"%price)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 price="99.5"
# ----> 2 print("The price is %d"%price)
#
# TypeError: %d format: a real number is required, not str

# %%
name="satheesh"
course="Python"

print("My name is {} and my course is {}".format(name,course))
# Out:
# My name is satheesh and my course is Python

# %% [markdown]
# ### f string method

# %%
name="satheesh"
age=21

print(f"my name is {name} and my age is {age}")
# Out:
# my name is satheesh and my age is 21

# %%
value=6.799
print("%d" % value)
# Out:
# 6

# %%
name="Satheesh"
age=21
print("My name is %s and I am %d years old"%(name,age))
# Out:
# My name is Satheesh and I am 21 years old

# %% [markdown]
# ## challange

# %%
name=input("enter the name:")
Age=int(input("Enter the age:"))
salary=int(input())

print(f"Hello {name},you are {age}
yearss old and your Salary is{salary}")
# Out:
# enter the name: satheesh
# Enter the age: 18
#  9000
# Hello satheesh,you are 21 yearss old and your Salary is9000
