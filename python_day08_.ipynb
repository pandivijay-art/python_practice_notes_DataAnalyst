# %% [markdown]
# ## Logical Or Gate

# %% [markdown]
# ### Take the n number of Objext among the given , if all the value is False then return the last false Value ,else return the first true Value

# %%
0 or 9 or 10
# Out:
# 9

# %%
9 or 10 or 11
# Out:
# 9

# %%
0 or 10
# Out:
# 10

# %%
10 or 11
# Out:
# 10

# %%
0 or 10 or [] or 90
# Out:
# 10

# %%
0 or [] or ()
# Out:
# ()

# %%
False and print("hello")
# Out:
# False

# %%
print("Hello") or print("satheesh")
# Out:
# Hello
# satheesh

# %%
(9>10) or (10>19)
# Out:
# False

# %% [markdown]
# ### Short Circuting in Logical Operater

# %% [markdown]
# ####  Short Circuting is the behavior when python program Stop evailuting remaing part of a logical expression ,because already determine the result.

# %% [markdown]
# for exmaple

# %%
0 and  [] and "satheesh"
# Out:
# 0

# %% [markdown]
# ### define Logical Not

# %% [markdown]
# take One Operand , and evoluting the trueth and return the opposite Boolean Values

# %% [markdown]
# for exmaple

# %%
not []
# Out:
# True

# %%
s=["satjheesh"]
not s
# Out:
# False

# %% [markdown]
# ### What is id()

# %% [markdown]
# #### Return the numeric address of given object

# %% [markdown]
# ### Cpython Cache Commently used for small integer object to improve performancfe and reduce unnessary object creattion .
# small cache integers -5 to 256

# %%
a=257
b=257
print(id(a))
print(id(b))
# Out:
# 1347196187280
# 1347196180368

# %%
a=[8]
b=[8]
print(id(a))
print(id(b))
# Out:
# 1347199096640
# 1347199095680

# %%
a=10
a=19
print(a)
# Out:
# 19

# %% [markdown]
# ### Identical operater

# %% [markdown]
# ### identify object used to determine two refernce point to the same object in memory.

# %% [markdown]
# ### is Operater

# %% [markdown]
# ### if two object refer the same address ,then return true.

# %%
a=8
b=9
a is b
# Out:
# False

# %%
a=[8]
b=[8]
a is b
# Out:
# False

# %% [markdown]
# ### is not Operater

# %% [markdown]
# ### if two object not  refer the  same object ,thyen return true

# %%
a=8
b=8
print(a is not b)
# Out:
# False

# %%
a=[8]
b=[8]
a is not b
# Out:
# True

# %% [markdown]
# ### diff between == and is operater

# %% [markdown]
# * ==  ( check the values or content)
# * is (check the address)

# %% [markdown]
# ### Membership Operater

# %% [markdown]
# Membership operter used to check an existing elemnt

# %% [markdown]
# ### in operter
#  if the given element exist on the sequence ,then return the true,otherwise false

# %% [markdown]
# ### in Not operater

# %% [markdown]
# #### if the given elemnt not existing in the sequence then return true ,otherwise false

# %%
li=[12,20,40]
12 not in li
# Out:
# False

# %% [markdown]
# ### Identical operter
