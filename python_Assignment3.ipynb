# %% [markdown]
# ### Assignment 3

# %% [markdown]
# ### 1.Arithmetic Operater and Assignment operater

# %% [markdown]
# #### Addition

# %%
x="Satheesh"
y="pandi"
print(x+y)
# Out:
# Satheeshpandi

# %%
x=90
y=90
x=x+10
print(x+y)
print(x)
# Out:
# 190
# 100

# %%
x="Satheesh"
y="90"
print(x+y)
# Out:
# Satheesh90

# %%
x=90.9
y=None
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 x=90.9
#       2 y=None
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'NoneType'

# %%
x=5+9j
y=None
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 x=5+9j
#       2 y=None
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'complex' and 'NoneType'

# %% [markdown]
# #### Subtraction

# %%
x="Satheesh"
y="pandi"
print(x-y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 x="Satheesh"
#       2 y="pandi"
# ----> 3 print(x-y)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
x=90
y=120
x=x-40
print(x-y)
print(x)
# Out:
# -70
# 50

# %%
x="Satheesh"
y=900
print(x-y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 x="Satheesh"
#       2 y=900
# ----> 3 print(x-y)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %% [markdown]
# ### 3.Multiplication

# %%
x=10
y=20
x=x*6
print(x)
print(x*y)
# Out:
# 60
# 1200

# %%
x="satheesh"
y="pandi"
print(x*y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 x="satheesh"
#       2 y="pandi"
# ----> 3 print(x*y)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
x=None
y=None
print(x*y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 x=None
#       2 y=None
# ----> 3 print(x*y)
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'NoneType'

# %%
x="90"
y="90.0"
print(x*y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 x="90"
#       2 y="90.0"
# ----> 3 print(x*y)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
mark=[10,20,30,40]
mal=[20,30,40,50]
print(mark-mal)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 mark=[10,20,30,40]
#       2 mal=[20,30,40,50]
# ----> 3 print(mark-mal)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
x="satheesh"
y=8
print(x*y)
# Out:
# satheeshsatheeshsatheeshsatheeshsatheeshsatheeshsatheeshsatheesh

# %% [markdown]
# ### String Repetition - Repeating the same String Multiple times using multiplecation operater

# %% [markdown]
# ## division

# %%
x=100
y=10
x=x/10.8
print(x)
print(x/y)
# Out:
# 9.25925925925926
# 0.9259259259259259

# %%
x="Satheesh"
y="100"
print(x/y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 x="Satheesh"
#       2 y="100"
# ----> 3 print(x/y)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# ## modulas

# %%
x=10
y=3
print(x%y)
x=x/20
print(x)
# Out:
# 1
# 0.5

# %%
x=10.9
y=90.9
print(x%y)
# Out:
# 10.9

# %%
x=10
y=10.9
print(x%y)
# Out:
# 10.0

# %% [markdown]
# ## Floor division

# %%
x=10
y=3
print(x//y)
x=x//3
print(x)
# Out:
# 3
# 3

# %%
x="satheesh"
y=100
print(x//y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 x="satheesh"
#       2 y=100
# ----> 3 print(x//y)
#
# TypeError: unsupported operand type(s) for //: 'str' and 'int'

# %%
x=10.89
y=1998.909
print(x//y)
# Out:
# 0.0

# %%
x=1000.89
y=189.09
print(x//y)
# Out:
# 5.0

# %% [markdown]
# ## Power

# %%
x=9
y=10
print(x**y)
x=x**3
print(x)
# Out:
# 3486784401
# 729

# %%
x=78.9
y=10.9
print(x**y)
# Out:
# 4.765838649932186e+20
