# %% [markdown]
# ## Commands

# %% [markdown]
# #### commands are line we are not exsicuted by compiler,that makes code easy and used to write notes about the code and debugging purpose.
# * ### Only Single Line Command
# * ####  That Can be used for <#>

# %% [markdown]
# #### Example of command

# %%
# print("hii")

# %% [markdown]
# ### Definison of print- print is a build in function that takes argument and return the output in console.

# %% [markdown]
# ## 2.Variable in python

# %% [markdown]
# #### in python variable a identifier  to refernces a stores object

# %% [markdown]
# ### How do stores a Variable

# %% [markdown]
# #### we can use a - z uppercases or lowercases or _ in python

# %%
Name="Satheesh"
print(Name)
# Out:
# Satheesh

# %% [markdown]
# ### 3. Rules to define a variable

# %% [markdown]
# #### 1.no numberic values in first place of variable

# %%
2apple=90
# Out:
#   Cell In[9], line 1
#     2apple=90
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# #### 2. Special Character is Not Allowed in Variable (ANyware) (each special character is operater so we cannot use)

# %%
@apple=90
# Out:
#   Cell In[15], line 1
#     @apple=90
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# ### 3.Keywords is also know as reserved Words,so we cannot use (mugup words) (alreay have a own meaning,dont assign new Meaning)

# %%
if=100
# Out:
#   Cell In[16], line 1
#     if=100
#       ^
# SyntaxError: invalid syntax

# %%
and=20
# Out:
#   Cell In[18], line 1
#     and=20
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 4. case senesitive

# %%
python=100
Print(python)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 python=100
# ----> 2 Print(python)
#
# NameError: name 'Print' is not defined

# %% [markdown]
# #### (name error)-name error will happen at the time calling an  is Not Defined

# %% [markdown]
# ### 5.No Spaces are allowed in Variable (undescore database-that is called)

# %%
pyrhon day=100
# Out:
#   Cell In[20], line 1
#     pyrhon day=100
#            ^
# SyntaxError: invalid syntax

# %%
pythonDay=10
pythonDay
# Out:
# 10

# %% [markdown]
# ## 4.what about Constant and private variables?

# %% [markdown]
# ###  to initiate a fellow developer a variable  as constant we use all chrs as upper Case

# %%
APPLE=10
APPLE=150
print(APPLE)
# Out:
# 150

# %% [markdown]
# #### FUll uppercase variable means (just inticate to fellow developer this is constant value should not be Changed ) just inticarte Word

# %% [markdown]
# ### use private key (in python use __ )

# %% [markdown]
# ### 5.Data Types

# %% [markdown]
# #### there are two Types

# %% [markdown]
# ### 1.Primitive DataType

# %% [markdown]
# #### the actual values you cannot be break and broken into small meaningfull parts

# %% [markdown]
# ### for exmaple: int,string ,float,boolean,none ,complex
#
# * whole numbers - integers,binary(0,1),octal(0,7),hexadeciamal(0,7)(a,to f),deciamal(0,9),

# %%
a=0b101
a
# Out:
# 5

# %% [markdown]
#  ### 2.Non Primitive Data Type

# %% [markdown]
# ## ex:array,list,tuble,dictionary

# %% [markdown]
# ### That can be broken

# %% [markdown]
# ### in general -sequnece of charcters -- string

# %% [markdown]
# #### in python- anything in defined in '',"",''', is called String

# %% [markdown]
# ## Syntax Error

# %% [markdown]
# #### Syntax error Means is a error that occur when python code does not follow language rules.

# %% [markdown]
# ## Name Error

# %% [markdown]
# #### occur when we are try to use variable that not has been Defined

# %% [markdown]
# ## Simple example of Day 3

# %% [markdown]
# #### Write a program to store a student name,age,and course using Variable and display tha all values

# %%
Student_name="Satheesh"
Student_age=20
Student_Course="B.Sc Computer Science"

print("The student name is:",Student_name)
print("The Student Age is:",Student_age)
print("THe Student COurse is:",Student_Course)
# Out:
# The student name is: Satheesh
# The Student Age is: 20
# THe Student COurse is: B.Sc Computer Science

# %% [markdown]
# # THE END
