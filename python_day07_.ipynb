# %% [markdown]
# ##
# operater

# %% [markdown]
# ### operater takes more then one operand and executes certain operations on then and generate output

# %%
# for exmple : 8 +9 -- here "+" operater

# %% [markdown]
# ### operands
#
# the object that getting operaterd by the operation we call them operands

# %%
# for exmple : 8 +9 -- here "8" and "9" operaands

# %% [markdown]
# ### 7 types of operater

# %% [markdown]
# * 1.Arithmetic operater
# * 2assignment operater
# * 3.comparision
# * 4.logical
# * 5.bitwise
# * 6.identify operater

# %% [markdown]
# Arithmetic operater
#
# they are immutable operations ,,they fall in 7 types
# * = -- addition
# * '-' -- subtraction
# * '*" -- multiplication  (advance level of addition ,take one value and additing
# * '/" -- division
# * "%" -- reminder (you take the denamiter ,and blance remaining)
# * '**' --  power 5**3 ( advnce level of multiplication ) (1st one is base and second one is power)
# * '//' -- floor division (remove the float division )
# *
# * immutable value(cannot be change and cannot be modified)

# %%
a =5
b=3

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 2
# 1

# %% [markdown]
# ### 2.Assignment Operater

# %% [markdown]
# ### we use arithmetic operater but we store the output into our variable only (every single operaton can be changed)
#
# operater ,+=,-=,*=,/=,//=,%=,**=

# %%
a=5
a+=9
print(a)
# Out:
# 14

# %%
### 3.

# %% [markdown]
# ### ass3: use combination of datatype on the operater (a="".b=9) check arithmetic ,assignment ,

# %% [markdown]
# ### comparison operater

# %% [markdown]
# ### why does called relational operater?
# ####  this operater wont return same input datatype.always return boolean result.
#  '>' -- left operand should be grater then right operand in that case we get output as true remaining all the cases it be false

# %% [markdown]
# '<' -- left operand should be smaller then right operand in that case we get output as true ,remaing all the case it be false.

# %% [markdown]
# '>=' -- grater or equal -- left operand should be grater or equal then right operand in that case we get output as true remaining all the cases it be false

# %% [markdown]
# '<=' -- lessthen or equal -- lesser or equal

# %% [markdown]
# '==' -- eqaulity-- left opernd equal  be equal to right operand

# %% [markdown]
# '!=, -- inequality -- left opernd equal not  be equal to right operand

# %%
compare the sequence (first element)

# %%
a="nosql"
b="mysql"

a>b
# Out:
# True

# %%
x="19.9"
y="Satheesh"
print(x>y)
# Out:
# False

# %% [markdown]
# #### logical operater

# %% [markdown]
# * unlike comparison logical operater will return same data type
#
# and -- (if the provided all the values are true last object  as a output,if any one object false also the false object wiil be the output)

# %%
8 and "hello" and 9+6j(9+6j)
# Out:
# (9+6j)

# %%
8 and [] and "hello"
# Out:
# []

# %%
(9>8) and (10>9)
# Out:
# True

# %%
9 and 7
# Out:
# 7

# %%
"hello" and "Satheesh" and "lkk"
# Out:
# 'lkk'

# %% [markdown]
# ## Practice question forDay7

# %%
x="python"
y="python"

print(x==y)
print(x>y)
# Out:
# True
# False

# %% [markdown]
# #### in python ,string Comparision is alwayes start in the first element ,(python cannot understand elemntds direstly so we use ASCII ,ASCII assign unique code for every sequence ,so if compare the string ,python check the first elemnt in the object based on ascii code and provide the output)

# %% [markdown]
# ### comparison operater result always boolean Values(return true or False)
